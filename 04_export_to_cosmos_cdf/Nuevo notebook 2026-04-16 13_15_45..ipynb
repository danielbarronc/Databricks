# %%
# %sql
SELECT COUNT(DISTINCT part_number) FROM parts.bronze.screws_bolts;

# %%
# %sql
SELECT COUNT(DISTINCT part_number) FROM parts.bronze.gaskets;

# %%
# %sql
SELECT COUNT(DISTINCT part_number) FROM parts.bronze.bushings;
