# %%
# %sql
USE CATALOG parts;
USE SCHEMA bronze;

DROP TABLE IF EXISTS parts.bronze.excel_s_20250912_part_data_entry_day_9_v2_screws_bolts;
DROP TABLE IF EXISTS parts.bronze.excel_s_20250912_part_data_entry_day_9_v2_gaskets;
DROP TABLE IF EXISTS parts.bronze.excel_s_20250912_part_data_entry_day_9_v2_bushings;
