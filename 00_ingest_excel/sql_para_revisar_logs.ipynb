# %%
# %sql
SELECT
  job_id,
  run_id,
  task_key,
  result_state,
  termination_code,
  period_start_time,
  period_end_time
FROM system.lakeflow.job_task_run_timeline
WHERE job_id = '55430712424432'
  AND result_state <> 'SUCCESS'
ORDER BY period_end_time DESC
LIMIT 100;

# %%
# %sql
SELECT *
FROM parts.bronze.autoloader_logs;
