# %%
spark.conf.get("fs.azure.account.key.datablobstorage001.dfs.core.windows.net", "NOT_SET")

# %%
spark.conf.get("fs.azure.account.key.datablobstorage001.blob.core.windows.net", "NOT_SET")

# %%
# %sql
SHOW EXTERNAL LOCATIONS;

# %%
# %sql
DESCRIBE EXTERNAL LOCATION datablobstorge001;

# %%
spark.conf.get("spark.databricks.unityCatalog.enabled", "false")

# %%
spark.conf.get("spark.databricks.clusterUsageTags.sparkVersion", "unknown")

# %%
dbutils.fs.ls("abfss://blobstorage@datablobstorage001.dfs.core.windows.net/")
